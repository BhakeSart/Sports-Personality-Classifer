# %%
import cv2

# %%
import numpy

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
img=cv2.imread("/Users/sarthak/Desktop/Sports_Personality_ Image_Classification/model/sample_images/sharapova1.jpg")

# %%
img.shape
# Out:
# (555, 700, 3)

# %%
plt.imshow(img);

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
gray.shape
# Out:
# (555, 700)

# %%
gray
# Out:
# array([[175, 175, 175, ..., 176, 175, 174],
#        [175, 175, 175, ..., 177, 175, 174],
#        [175, 175, 175, ..., 177, 176, 174],
#        ...,
#        [ 84,  87,  88, ..., 113, 113, 113],
#        [ 88,  89,  90, ..., 113, 113, 113],
#        [ 93,  91,  91, ..., 112, 112, 112]], dtype=uint8)

# %%
 plt.imshow(gray , cmap="gray");

# %%
face_cascade=cv2.CascadeClassifier("/Users/sarthak/Desktop/test/CelebrityFaceRecognition/model/opencv/haarcascades/haarcascade_frontalface_default.xml")

# %%
eye_cascade=cv2.CascadeClassifier("/Users/sarthak/Desktop/test/CelebrityFaceRecognition/model/opencv/haarcascades/haarcascade_eye.xml")

# %%
faces=face_cascade.detectMultiScale(gray,1.3,5)

# %%
faces #cor-ordinates of the face(start,finish,height,width)
# Out:
# array([[352,  38, 233, 233]], dtype=int32)

# %%
(x,y,w,h)=faces[0]

# %%
x,y,w,h
# Out:
# (352, 38, 233, 233)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)

# %%
plt.imshow(face_img);

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
plt.imshow(roi_color,cmap="gray");

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
cropped_img=get_cropped_image_if_2_eyes("/Users/sarthak/Desktop/Sports_Personality_ Image_Classification/model/sample_images/sharapova1.jpg")

# %%
plt.imshow(cropped_img);

# %%
no_eyes=get_cropped_image_if_2_eyes("/Users/sarthak/Desktop/Sports_Personality_ Image_Classification/model/sample_images/sharapova2.JPG")

# %%
no_eyes

# %%
path_to_data="/Users/sarthak/Desktop/Sports_Personality_ Image_Classification/model/dataset"
path_to_cr_data="/Users/sarthak/Desktop/Sports_Personality_ Image_Classification/model/dataset/cropped/"

# %%
import os 
img_dirs=[]
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['/Users/sarthak/Desktop/Sports_Personality_ Image_Classification/model/dataset/maria_sharapova',
#  '/Users/sarthak/Desktop/Sports_Personality_ Image_Classification/model/dataset/virat_kohli',
#  '/Users/sarthak/Desktop/Sports_Personality_ Image_Classification/model/dataset/lionel_messi',
#  '/Users/sarthak/Desktop/Sports_Personality_ Image_Classification/model/dataset/serena_williams',
#  '/Users/sarthak/Desktop/Sports_Personality_ Image_Classification/model/dataset/roger_federer']

# %%
import shutil

# %%
if os.path.exists(path_to_cr_data):
    shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_img_dirs=[]
sports_file_names={}
for img_dir in img_dirs:
    count=1
    sports_name=img_dir.split("/")[-1]
    sports_file_names[sports_name]=[]
    for entry in os.scandir(img_dir):
        roi_color=get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder=path_to_cr_data + sports_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_img_dirs.append(cropped_folder)
                print("Rendering Cropped Images are in folder : ",cropped_folder)
    
            cropped_file_name=sports_name +str(count) + ".png"
            cropped_file_path=cropped_folder + "/" + cropped_file_name
            
            cv2.imwrite(cropped_file_path , roi_color)
            sports_file_names[sports_name].append(cropped_file_path)
            count+=1

# %% [markdown]
# ## Feature Engg using Wavelet transform

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har,cmap="gray");

# %% [markdown]
# vertically stacking the raw and transformed images

# %%
sports_file_names
# Out:
# {'maria_sharapova': ['/Users/sarthak/Desktop/Sports_Personality_ Image_Classification/model/dataset/cropped/maria_sharapova/maria_sharapova1.png',
#   '/Users/sarthak/Desktop/Sports_Personality_ Image_Classification/model/dataset/cropped/maria_sharapova/maria_sharapova2.png',
#   '/Users/sarthak/Desktop/Sports_Personality_ Image_Classification/model/dataset/cropped/maria_sharapova/maria_sharapova3.png',
#   '/Users/sarthak/Desktop/Sports_Personality_ Image_Classification/model/dataset/cropped/maria_sharapova/maria_sharapova4.png',
#   '/Users/sarthak/Desktop/Sports_Personality_ Image_Classification/model/dataset/cropped/maria_sharapova/maria_sharapova5.png',
#   '/Users/sarthak/Desktop/Sports_Personality_ Image_Classification/model/dataset/cropped/maria_sharapova/maria_sharapova6.png',
#   '/Users/sarthak/Desktop/Sports_Personality_ Image_Classification/model/dataset/cropped/maria_sharapova/maria_sharapova7.png',
# ...

# %%
class_dict={}
count=1
for sports_name in sports_file_names.keys():
    class_dict[sports_name]=count
    count=count+1
class_dict
# Out:
# {'maria_sharapova': 1,
#  'virat_kohli': 2,
#  'lionel_messi': 3,
#  'serena_williams': 4,
#  'roger_federer': 5}

# %%
X=[]
y=[]
for sports_name , training_files in sports_file_names.items():
    for training_img in training_files:
        img=cv2.imread(training_img)
        if img is None:
            continue
        scaled_raw_images=cv2.resize(img,(32,32))
        img_har=w2d(img,"db1",5)
        scaled_har_images=cv2.resize(img_har,(32,32))
        combined_img = np.vstack((scaled_raw_images.reshape(32*32*3,1),scaled_har_images.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[sports_name])
# Out:
# [ WARN:0@5099.231] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/Users/sarthak/Desktop/Sports_Personality_ Image_Classification/model/dataset/cropped/maria_sharapova/maria_sharapova21.png'): can't open/read file: check file path/integrity
# [ WARN:0@5099.248] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/Users/sarthak/Desktop/Sports_Personality_ Image_Classification/model/dataset/cropped/maria_sharapova/maria_sharapova27.png'): can't open/read file: check file path/integrity
# [ WARN:0@5099.266] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/Users/sarthak/Desktop/Sports_Personality_ Image_Classification/model/dataset/cropped/virat_kohli/virat_kohli2.png'): can't open/read file: check file path/integrity
# ...

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
len(y)
# Out:
# 171

# %%
X = np.array(X).reshape(len(X),4096).astype(float)

# %%
X.shape
# Out:
# (171, 4096)

# %% [markdown]
# Model Training

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('svc', SVC(C=10))])

# %%
pipe.score(X_test, y_test)
# Out:
# 0.7674418604651163

# %%
len(X_test)
# Out:
# 43

# %%
print(classification_report(y_test,pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.83      0.62      0.71         8
#            2       0.75      1.00      0.86        12
#            3       1.00      0.82      0.90        11
#            4       0.50      0.50      0.50         6
#            5       0.67      0.67      0.67         6
#
#     accuracy                           0.77        43
#    macro avg       0.75      0.72      0.73        43
# weighted avg       0.78      0.77      0.77        43

# %% [markdown]
# hyperparameter tuning

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.819692
# 1        random_forest    0.647692
# 2  logistic_regression    0.835385
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                 {'logisticregression__C': 10}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=10, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.813953488372093

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.6976744186046512

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.813953488372093

# %%
best_clf = best_estimators['logistic_regression']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 5,  0,  0,  2,  1],
#        [ 0, 11,  1,  0,  0],
#        [ 0,  0, 10,  1,  0],
#        [ 0,  1,  0,  5,  0],
#        [ 1,  0,  0,  1,  4]])

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth');

# %%
class_dict
# Out:
# {'maria_sharapova': 1,
#  'virat_kohli': 2,
#  'lionel_messi': 3,
#  'serena_williams': 4,
#  'roger_federer': 5}

# %%
import joblib

# %%
joblib.dump(best_clf,"final_model.pkl")
# Out:
# ['final_model.pkl']

# %%
import json
with open("class_dictonary.json","w") as f:
    f.write(json.dumps(class_dict))
